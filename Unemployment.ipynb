# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

Unemployment_data=pd.read_csv("./Unemployment in India.csv")
Unemployment_data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df=pd.DataFrame(data=Unemployment_data)
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 749  West Bengal   29-02-2020    Monthly                              7.55
# 750  West Bengal   31-03-2020    Monthly                              6.67
# 751  West Bengal   30-04-2020    Monthly                             15.63
# 752  West Bengal   31-05-2020    Monthly                             15.22
# 753  West Bengal   30-06-2020    Monthly                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 749           10871168.0                                     44.09  Urban
# 750           10806105.0                                     43.34  Urban
# 751            9299466.0                                     41.20  Urban
# 752            9240903.0                                     40.67  Urban
# 753            9088931.0                                     37.57  Urban

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %%
df.sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# ...

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df.iloc[[100]]
# Out:
#       Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 100  Haryana   30-11-2019    Monthly                             16.59
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 100            4875763.0                                     42.48  Rural

# %%
df.count()
# Out:
# Region                                      740
#  Date                                       740
#  Frequency                                  740
#  Estimated Unemployment Rate (%)            740
#  Estimated Employed                         740
#  Estimated Labour Participation Rate (%)    740
# Area                                        740
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Region                                      14
#  Date                                       14
#  Frequency                                  14
#  Estimated Unemployment Rate (%)            14
#  Estimated Employed                         14
#  Estimated Labour Participation Rate (%)    14
# Area                                        14
# dtype: int64

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df_g=df.groupby('Region')['Area'].apply(lambda x:x.mode().iloc[0]).reset_index()
df_g.columns=['Region','Mode_Area']
df_g
# Out:
#               Region Mode_Area
# 0     Andhra Pradesh     Rural
# 1              Assam     Urban
# 2              Bihar     Rural
# 3         Chandigarh     Urban
# 4       Chhattisgarh     Rural
# 5              Delhi     Rural
# 6                Goa     Rural
# 7            Gujarat     Rural
# 8            Haryana     Rural
# 9   Himachal Pradesh     Rural
# 10   Jammu & Kashmir     Rural
# 11         Jharkhand     Rural
# 12         Karnataka     Rural
# 13            Kerala     Rural
# 14    Madhya Pradesh     Rural
# 15       Maharashtra     Rural
# 16         Meghalaya     Rural
# 17            Odisha     Rural
# 18        Puducherry     Urban
# 19            Punjab     Rural
# 20         Rajasthan     Rural
# 21            Sikkim     Urban
# 22        Tamil Nadu     Rural
# 23         Telangana     Rural
# 24           Tripura     Rural
# 25     Uttar Pradesh     Rural
# 26       Uttarakhand     Urban
# 27       West Bengal     Rural

# %%
df.isnull().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region     14
# 1                                      Date     14
# 2                                 Frequency     14
# 3           Estimated Unemployment Rate (%)     14
# 4                        Estimated Employed     14
# 5   Estimated Labour Participation Rate (%)     14
# 6                                      Area     14

# %%
df.loc[df['Region'].isna()]
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 359    NaN   NaN        NaN                               NaN
# 360    NaN   NaN        NaN                               NaN
# 361    NaN   NaN        NaN                               NaN
# 362    NaN   NaN        NaN                               NaN
# 363    NaN   NaN        NaN                               NaN
# 364    NaN   NaN        NaN                               NaN
# 365    NaN   NaN        NaN                               NaN
# 366    NaN   NaN        NaN                               NaN
# 367    NaN   NaN        NaN                               NaN
# 368    NaN   NaN        NaN                               NaN
# 369    NaN   NaN        NaN                               NaN
# 370    NaN   NaN        NaN                               NaN
# 371    NaN   NaN        NaN                               NaN
# 372    NaN   NaN        NaN                               NaN
#
# ...

# %%
df["Region"].unique
# Out:
# <bound method Series.unique of 0      Andhra Pradesh
# 1      Andhra Pradesh
# 2      Andhra Pradesh
# 3      Andhra Pradesh
# 4      Andhra Pradesh
#             ...
# 749       West Bengal
# 750       West Bengal
# 751       West Bengal
# 752       West Bengal
# 753       West Bengal
# Name: Region, Length: 754, dtype: object>

# %%
df["Region"].value_counts().reset_index()
# Out:
#               Region  count
# 0     Andhra Pradesh     28
# 1             Kerala     28
# 2        West Bengal     28
# 3      Uttar Pradesh     28
# 4            Tripura     28
# 5          Telangana     28
# 6         Tamil Nadu     28
# 7          Rajasthan     28
# 8             Punjab     28
# 9             Odisha     28
# 10    Madhya Pradesh     28
# 11       Maharashtra     28
# 12         Karnataka     28
# 13         Jharkhand     28
# 14  Himachal Pradesh     28
# 15           Haryana     28
# 16           Gujarat     28
# 17             Delhi     28
# 18      Chhattisgarh     28
# 19             Bihar     28
# 20         Meghalaya     27
# 21       Uttarakhand     27
# 22             Assam     26
# 23        Puducherry     26
# 24               Goa     24
# 25   Jammu & Kashmir     21
# 26            Sikkim     17
# 27        Chandigarh     12

# %%
df["Area"]=df["Area"].fillna(df["Area"].mode()[0])
df["Area"]=df.groupby("Region")["Area"].transform(lambda x:x.fillna(x.mode().iloc[0]))

# %%
df.isna().sum().reset_index().rename(columns={0:'count'})
# Out:
#                                       index  count
# 0                                    Region     14
# 1                                      Date     14
# 2                                 Frequency     14
# 3           Estimated Unemployment Rate (%)     14
# 4                        Estimated Employed     14
# 5   Estimated Labour Participation Rate (%)     14
# 6                                      Area     14

# %%
df["Region"].describe()
# Out:
# count                740
# unique                28
# top       Andhra Pradesh
# freq                  28
# Name: Region, dtype: object

# %%
df1["Region"].unique()
# Out:
# array([nan], dtype=object)

# %%
df1=df.loc[df["Area"].isna(),"Region"].reset_index()
df1
# Out:
#     index Region
# 0     359    NaN
# 1     360    NaN
# 2     361    NaN
# 3     362    NaN
# 4     363    NaN
# 5     364    NaN
# 6     365    NaN
# 7     366    NaN
# 8     367    NaN
# 9     368    NaN
# 10    369    NaN
# 11    370    NaN
# 12    371    NaN
# 13    372    NaN

# %%
df1["Region"].value_counts().reset_index()
# Out:
# Empty DataFrame
# Columns: [Region, count]
# Index: []

# %%
sns.countplot(x=df["Region"],hue=df["Area"])
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
dfl=df[df['Area']!=0]
dfl.loc[dfl['Region']==0,'Region']=np.nan
dfl.head(10)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5  Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6  Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7  Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8  Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9  Andhra Pradesh   29-02-2020    Monthly                              5.91
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %%
dfl.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
plt.figure(figsize=(10,6))
sns.displot(data=Unemployment_data,x='Area',color="orange")
plt.title("Distribution of Area")
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dfl.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# ...

# %%
df["Area"].reset_index()
# Out:
#      index   Area
# 0        0  Rural
# 1        1  Rural
# 2        2  Rural
# 3        3  Rural
# 4        4  Rural
# ..     ...    ...
# 749    749  Urban
# 750    750  Urban
# 751    751  Urban
# 752    752  Urban
# 753    753  Urban
#
# [754 rows x 2 columns]

# %%
df["Region"].isna().sum()
# Out:
# 14

# %%
dfl.count()
# Out:
# Region                                      740
#  Date                                       740
#  Frequency                                  740
#  Estimated Unemployment Rate (%)            740
#  Estimated Employed                         740
#  Estimated Labour Participation Rate (%)    740
# Area                                        740
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Unemployment_data,x='Region',bins=15,kde=True,color="Blue")
plt.title("Distribution of Region")
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Unemployment_data,x='Area',kde=True,color="Green")
plt.title("Distribution of Area")
plt.xlabel('Area')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
dfl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %%
df["Region"].reset_index()
# Out:
#      index          Region
# 0        0  Andhra Pradesh
# 1        1  Andhra Pradesh
# 2        2  Andhra Pradesh
# 3        3  Andhra Pradesh
# 4        4  Andhra Pradesh
# ..     ...             ...
# 749    749     West Bengal
# 750    750     West Bengal
# 751    751     West Bengal
# 752    752     West Bengal
# 753    753     West Bengal
#
# [754 rows x 2 columns]

# %%
df["Region"].describe()
# Out:
# count                740
# unique                28
# top       Andhra Pradesh
# freq                  28
# Name: Region, dtype: object

# %%
df.Area.value_counts().plot(kind='bar',figsize=(10,6))
# Out:
# <Axes: xlabel='Area'>

# %%
df.Region.value_counts()
# Out:
# Region
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
df.Region.value_counts().plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='Region'>
